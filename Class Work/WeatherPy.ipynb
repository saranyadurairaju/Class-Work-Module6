# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
cities
# Out:
# ['nuevitas',
#  'kapaa',
#  'busselton',
#  'novokizhinginsk',
#  'bay roberts',
#  'kahului',
#  'hilo',
#  'yellowknife',
#  'wajima',
#  'camana',
#  'logan',
#  'bluff',
#  'ushuaia',
#  'dingle',
#  'atuona',
#  'attawapiskat',
#  'vaini',
#  'lebu',
#  'bardiyah',
#  'georgetown',
#  'albany',
#  'port blair',
#  'hualmay',
#  'klaksvik',
#  'vaitupu',
#  'novo aripuana',
#  'flinders',
#  'pevek',
#  'thompson',
#  'taolanaro',
#  'whitehorse',
#  'mahebourg',
#  'hinton',
#  'kodiak',
#  'punta arenas',
#  'rikitea',
#  'ancud',
#  'chiredzi',
#  'muriwai beach',
#  'chokurdakh',
#  'mys shmidta',
#  'weihe',
#  'hermanus',
#  'gorontalo',
#  'victoria',
#  'yulara',
#  'saint-philippe',
#  'puerto el triunfo',
#  'ler',
#  'itagi',
#  'barinitas',
#  'khatanga',
#  'richards bay',
#  'mocambique',
#  'sapucaia',
#  'xichang',
#  'tiksi',
#  'tasiilaq',
#  'buala',
#  'the valley',
#  'seminole',
#  'torbay',
#  'dickinson',
#  'portree',
#  'dikson',
#  'tsihombe',
#  'fairbanks',
#  'marcona',
#  'kununurra',
#  'mount isa',
#  'tambo grande',
#  'hambantota',
#  'puerto ayora',
#  'isangel',
#  'taoudenni',
#  'ngukurr',
#  'phnum penh',
#  'hobart',
#  'veraval',
#  'kruisfontein',
#  'castro',
#  'bredasdorp',
#  'raudeberg',
#  'barentsburg',
#  'saskylakh',
#  'ponta delgada',
#  'vardo',
#  'sao filipe',
#  'jamestown',
#  'bella union',
#  'pacific grove',
#  'kamenka',
#  'guerrero negro',
#  'airai',
#  'ribeira grande',
#  'darnah',
#  'port alfred',
#  'grindavik',
#  'westport',
#  'brae',
#  'lempaala',
#  'hay river',
#  'butaritari',
#  'cape town',
#  'provideniya',
#  'bambanglipuro',
#  'bud',
#  'san patricio',
#  'sosnovo-ozerskoye',
#  'kailua',
#  'oistins',
#  'mozelos',
#  'goderich',
#  'qeshm',
#  'roma',
#  'qaanaaq',
#  'makamba',
#  'saint george',
#  'vila franca do campo',
#  'mataura',
#  'ahipara',
#  'rehoboth',
#  'iquitos',
#  'ilulissat',
#  'mar del plata',
#  'jacqueville',
#  'hithadhoo',
#  'east london',
#  'los llanos de aridane',
#  'burica',
#  'yen bai',
#  'moorhead',
#  'houma',
#  'georgiyevka',
#  'severo-kurilsk',
#  'verdun',
#  'vao',
#  'peterhead',
#  'rungata',
#  'bethel',
#  'codrington',
#  'ponta do sol',
#  'karasjok',
#  'adelaide',
#  'iqaluit',
#  'macaboboni',
#  'saint-joseph',
#  'belushya guba',
#  'ouesso',
#  'bafoulabe',
#  'kristinehamn',
#  'kamenskoye',
#  'rodrigues alves',
#  'nikolayevskaya',
#  'new norfolk',
#  'krasnoselkup',
#  'awjilah',
#  'yaqui',
#  'srednekolymsk',
#  'escarcega',
#  'cherskiy',
#  'samusu',
#  'avarua',
#  'tautira',
#  'sabang',
#  'deputatskiy',
#  'anloga',
#  'aflu',
#  'berlevag',
#  'palmer',
#  'coihaique',
#  'spokane',
#  'luganville',
#  'hasaki',
#  'kondinskoye',
#  'sentyabrskiy',
#  'emba',
#  'luba',
#  'boralday',
#  'mrirt',
#  'olenino',
#  'utiroa',
#  'riyadh',
#  'tolaga bay',
#  'poronaysk',
#  'annaka',
#  'olafsvik',
#  'manaure',
#  'leningradskiy',
#  'tuktoyaktuk',
#  'honiara',
#  'maltahohe',
#  'pisco',
#  'nizwa',
#  'suntar',
#  'mehamn',
#  'saquena',
#  'kananga',
#  'hami',
#  'nyimba',
#  'popondetta',
#  'pombas',
#  'mao',
#  'fort nelson',
#  'ostrovnoy',
#  'nanortalik',
#  'arlit',
#  'bengkulu',
#  'pochutla',
#  'chuy',
#  'volterra',
#  'nsanje',
#  'narsaq',
#  'coquimbo',
#  'pousat',
#  'messina',
#  'kismayo',
#  'lagoa',
#  'westlock',
#  'selma',
#  'talnakh',
#  'daru',
#  'preston',
#  'sept-iles',
#  'byron bay',
#  'tagab',
#  'bathsheba',
#  'carnarvon',
#  'beyneu',
#  'lixourion',
#  'yantai',
#  'kidal',
#  'inirida',
#  'mezen',
#  'odda',
#  'aykhal',
#  'baoning',
#  'nome',
#  'mackay',
#  'clyde river',
#  'rodos',
#  'karaul',
#  'ixtapa',
#  'upernavik',
#  'rio branco',
#  'kaitangata',
#  'tungor',
#  'taburi',
#  'marsabit',
#  'brownsville',
#  'santa rosa',
#  'baghmara',
#  'hofn',
#  'faanui',
#  'kota kinabalu',
#  'bunia',
#  'port elizabeth',
#  'alanya',
#  'mercedes',
#  'asau',
#  'hastings',
#  'arraial do cabo',
#  'dabou',
#  'vestmanna',
#  'brazzaville',
#  'walvis bay',
#  'batagay',
#  'seoul',
#  'vanavara',
#  'tiznit',
#  'marang',
#  'longyearbyen',
#  'amderma',
#  'barrow',
#  'katsuura',
#  'puerto escondido',
#  'port hardy',
#  'reserva',
#  'hamilton',
#  'jasdan',
#  'bozova',
#  'esperance',
#  'khartoum',
#  'aklavik',
#  'moree',
#  'falealupo',
#  'zabol',
#  'nsoko',
#  'parfenyevo',
#  'coldwater',
#  'palana',
#  'wainwright',
#  'eureka',
#  'illoqqortoormiut',
#  'adrar',
#  'merke',
#  'litovko',
#  'teknaf',
#  'benguela',
#  'aksu',
#  'geraldton',
#  'iranshahr',
#  'bintulu',
#  'taft',
#  'longlac',
#  'karratha',
#  'buariki',
#  'lompoc',
#  'teneguiban',
#  'perth',
#  'gulshat',
#  'vila velha',
#  'myitkyina',
#  'balikpapan',
#  'nizhniy odes',
#  'vostok',
#  'tumannyy',
#  'cam ranh',
#  'bollnas',
#  'grand river south east',
#  'kericho',
#  'ballina',
#  'lorengau',
#  'mackenzie',
#  'pouebo',
#  'nakamura',
#  'safita',
#  'bandarbeyla',
#  'west bay',
#  'cidreira',
#  'pangody',
#  'atherton',
#  'cuamba',
#  'pearl',
#  'sinkat',
#  'lakes entrance',
#  'omsukchan',
#  'nadym',
#  'grand centre',
#  'dicabisagan',
#  'coos bay',
#  'port keats',
#  'mpanda',
#  'laguna',
#  'najran',
#  'camopi',
#  'madinat sittah uktubar',
#  'alofi',
#  'sakakah',
#  'korla',
#  'tarn taran',
#  'yar-sale',
#  'khawhai',
#  'carmen',
#  'mugur-aksy',
#  'mananara',
#  'cabra',
#  'zhigansk',
#  'angoram',
#  'bambous virieux',
#  'abnub',
#  'nikolskoye',
#  'gobabis',
#  'mitsamiouli',
#  'bodden town',
#  'fallon',
#  'naze',
#  'bonavista',
#  'meulaboh',
#  'yusva',
#  'havre-saint-pierre',
#  'lhokseumawe',
#  'moquegua',
#  'mogadishu',
#  'tivaouane',
#  'yafran',
#  'gornja radgona',
#  'saint-augustin',
#  'tromso',
#  'lasa',
#  'nouadhibou',
#  'kenai',
#  'pilar',
#  'zhaoqing',
#  'constitucion',
#  'sohag',
#  'poum',
#  'yerbogachen',
#  'talavera de la reina',
#  'ossora',
#  'keti bandar',
#  'kainantu',
#  'izumo',
#  'norman wells',
#  'jatiroto',
#  'vikhorevka',
#  'umzimvubu',
#  'kralendijk',
#  'yiyang',
#  'la libertad',
#  'loukhi',
#  'juneau',
#  'outjo',
#  'ati',
#  'kavieng',
#  'ulaangom',
#  'hirara',
#  'maceio',
#  'ahar',
#  'san cristobal',
#  'conde',
#  'cuenca',
#  'havelock',
#  'gubbi',
#  'bull savanna',
#  'vandavasi',
#  'chunhuhub',
#  'kerman',
#  'wonthaggi',
#  'hella',
#  'nakskov',
#  'birjand',
#  'bandundu',
#  'tual',
#  'khonuu',
#  'gat',
#  'haines junction',
#  'jinchang',
#  'nova vicosa',
#  'nanning',
#  'nizhneyansk',
#  'paungde',
#  'vanimo',
#  'wangqing',
#  'port lincoln',
#  'raga',
#  'saldanha',
#  'sambava',
#  'mapiripan',
#  'millinocket',
#  'brokopondo',
#  'waitara',
#  'cabo san lucas',
#  'sorland',
#  'moose factory',
#  'bacuit',
#  'tuatapere',
#  'harnai',
#  'tacuarembo',
#  'keflavik',
#  'saint-paul',
#  'port-cartier',
#  'acari',
#  'hihifo',
#  'dunedin',
#  'muros',
#  'maniitsoq',
#  'mildura',
#  'methven',
#  'never',
#  'aleksandrovsk-sakhalinskiy',
#  'umm lajj',
#  'dombarovskiy',
#  'novyy urengoy',
#  'agadir',
#  'lufilufi',
#  'isla mujeres',
#  'mecca',
#  'perleberg',
#  'touros',
#  'marsa matruh',
#  'namuac',
#  'mayo',
#  'khandyga',
#  'broome',
#  'jos',
#  'wulanhaote',
#  'sao felix do xingu',
#  'manavalakurichi',
#  'carlagan',
#  'huangmei',
#  'namwala',
#  'chaozhou',
#  'dalbandin',
#  'pascagoula',
#  'aswan',
#  'mmabatho',
#  'berdigestyakh',
#  'vallenar',
#  'lovozero',
#  'wladyslawowo',
#  'tongchuan',
#  'baran',
#  'komsomolskiy',
#  'avera',
#  'high rock',
#  'kulhudhuffushi',
#  'tiarei',
#  'olinda',
#  'vieira de leiria',
#  'ippy',
#  'kavaratti',
#  'makakilo city',
#  'mitchell',
#  'komatipoort',
#  'kindu',
#  'ladario',
#  'manono',
#  'sibolga',
#  'cockburn town',
#  'manacapuru',
#  'asyut',
#  'grand-santi',
#  'haimen',
#  'copiapo',
#  'half moon bay',
#  'jiuquan',
#  'kostomuksha',
#  'freeport',
#  'samfya',
#  'lubu',
#  'namatanai',
#  'synya',
#  'haibowan',
#  'ducheng',
#  'biak',
#  'ciudad bolivar',
#  'annau',
#  'bilma',
#  'antofagasta',
#  'shache',
#  'nalut',
#  'great bend',
#  'malpe',
#  'sur',
#  'karatsu',
#  'huarmey',
#  'changchun',
#  'potosi',
#  'talcahuano',
#  'tilichiki',
#  'baruun-urt',
#  'manhattan',
#  'savonlinna',
#  'tura',
#  'nikki',
#  'savannah bight',
#  'katherine',
#  'show low',
#  'bosaso',
#  'lisakovsk',
#  'bilibino',
#  'wattegama',
#  'portland',
#  'shakawe',
#  'umm durman',
#  'rawson',
#  'lazaro cardenas',
#  'zhengjiatun',
#  'bam',
#  'kashi',
#  'vanderhoof',
#  'souillac',
#  'la reforma',
#  'atbasar',
#  'hengshan',
#  'monrovia',
#  'conakry',
#  'kawalu',
#  'loandjili',
#  'pinheiral',
#  'salekhard',
#  'kibala',
#  'caravelas',
#  'acajutla',
#  'lavrentiya',
#  'uusikaupunki',
#  'tazovskiy',
#  'mabaruma',
#  'val-david',
#  'blonduos',
#  'gunjur',
#  'tuggurt',
#  'neryungri',
#  'ruteng',
#  'nemuro',
#  'santa cruz',
#  'oktyabrskoye',
#  'kokopo',
#  'zyryanka',
#  'valparaiso',
#  'tunduru',
#  'alto araguaia',
#  'homer',
#  'esna',
#  'hals',
#  'grande-riviere',
#  'nelson bay',
#  'along',
#  'yatou',
#  'buraydah',
#  'omboue',
#  'marawi',
#  'chute-aux-outardes',
#  'dubti',
#  'tarakan',
#  'cotonou',
#  'llanes',
#  'sisimiut',
#  'maua',
#  'labuhan',
#  'kieta',
#  'beloha',
#  'banda aceh',
#  'sao fidelis',
#  'morrinhos',
#  'rupert',
#  'sehithwa',
#  'carballo',
#  'shediac',
#  'timbiqui',
#  'otradnoye',
#  'dudinka',
#  'halalo']

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nuevitas
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | novokizhinginsk
# Processing Record 5 of Set 1 | bay roberts
# Processing Record 6 of Set 1 | kahului
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | wajima
# Processing Record 10 of Set 1 | camana
# Processing Record 11 of Set 1 | logan
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | dingle
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | lebu
# Processing Record 19 of Set 1 | bardiyah
# Processing Record 20 of Set 1 | georgetown
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | port blair
# Processing Record 23 of Set 1 | hualmay
# Processing Record 24 of Set 1 | klaksvik
# Processing Record 25 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 1 | novo aripuana
# Processing Record 27 of Set 1 | flinders
# Processing Record 28 of Set 1 | pevek
# Processing Record 29 of Set 1 | thompson
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | whitehorse
# Processing Record 32 of Set 1 | mahebourg
# Processing Record 33 of Set 1 | hinton
# Processing Record 34 of Set 1 | kodiak
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | ancud
# Processing Record 38 of Set 1 | chiredzi
# Processing Record 39 of Set 1 | muriwai beach
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 1 | weihe
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | gorontalo
# Processing Record 45 of Set 1 | victoria
# Processing Record 46 of Set 1 | yulara
# Processing Record 47 of Set 1 | saint-philippe
# Processing Record 48 of Set 1 | puerto el triunfo
# Processing Record 49 of Set 1 | ler
# Processing Record 50 of Set 1 | itagi
# Processing Record 1 of Set 2 | barinitas
# Processing Record 2 of Set 2 | khatanga
# Processing Record 3 of Set 2 | richards bay
# Processing Record 4 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 5 of Set 2 | sapucaia
# Processing Record 6 of Set 2 | xichang
# Processing Record 7 of Set 2 | tiksi
# Processing Record 8 of Set 2 | tasiilaq
# Processing Record 9 of Set 2 | buala
# Processing Record 10 of Set 2 | the valley
# Processing Record 11 of Set 2 | seminole
# Processing Record 12 of Set 2 | torbay
# Processing Record 13 of Set 2 | dickinson
# Processing Record 14 of Set 2 | portree
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 2 | fairbanks
# Processing Record 18 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 2 | kununurra
# Processing Record 20 of Set 2 | mount isa
# Processing Record 21 of Set 2 | tambo grande
# Processing Record 22 of Set 2 | hambantota
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | isangel
# Processing Record 25 of Set 2 | taoudenni
# Processing Record 26 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 2 | phnum penh
# City not found. Skipping...
# Processing Record 28 of Set 2 | hobart
# Processing Record 29 of Set 2 | veraval
# Processing Record 30 of Set 2 | kruisfontein
# Processing Record 31 of Set 2 | castro
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | raudeberg
# Processing Record 34 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 2 | saskylakh
# Processing Record 36 of Set 2 | ponta delgada
# Processing Record 37 of Set 2 | vardo
# Processing Record 38 of Set 2 | sao filipe
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | bella union
# Processing Record 41 of Set 2 | pacific grove
# Processing Record 42 of Set 2 | kamenka
# Processing Record 43 of Set 2 | guerrero negro
# Processing Record 44 of Set 2 | airai
# Processing Record 45 of Set 2 | ribeira grande
# Processing Record 46 of Set 2 | darnah
# Processing Record 47 of Set 2 | port alfred
# Processing Record 48 of Set 2 | grindavik
# Processing Record 49 of Set 2 | westport
# Processing Record 50 of Set 2 | brae
# Processing Record 1 of Set 3 | lempaala
# Processing Record 2 of Set 3 | hay river
# Processing Record 3 of Set 3 | butaritari
# Processing Record 4 of Set 3 | cape town
# Processing Record 5 of Set 3 | provideniya
# Processing Record 6 of Set 3 | bambanglipuro
# Processing Record 7 of Set 3 | bud
# Processing Record 8 of Set 3 | san patricio
# Processing Record 9 of Set 3 | sosnovo-ozerskoye
# Processing Record 10 of Set 3 | kailua
# Processing Record 11 of Set 3 | oistins
# Processing Record 12 of Set 3 | mozelos
# Processing Record 13 of Set 3 | goderich
# Processing Record 14 of Set 3 | qeshm
# Processing Record 15 of Set 3 | roma
# Processing Record 16 of Set 3 | qaanaaq
# Processing Record 17 of Set 3 | makamba
# Processing Record 18 of Set 3 | saint george
# Processing Record 19 of Set 3 | vila franca do campo
# Processing Record 20 of Set 3 | mataura
# Processing Record 21 of Set 3 | ahipara
# Processing Record 22 of Set 3 | rehoboth
# Processing Record 23 of Set 3 | iquitos
# Processing Record 24 of Set 3 | ilulissat
# Processing Record 25 of Set 3 | mar del plata
# Processing Record 26 of Set 3 | jacqueville
# Processing Record 27 of Set 3 | hithadhoo
# Processing Record 28 of Set 3 | east london
# Processing Record 29 of Set 3 | los llanos de aridane
# Processing Record 30 of Set 3 | burica
# City not found. Skipping...
# Processing Record 31 of Set 3 | yen bai
# Processing Record 32 of Set 3 | moorhead
# Processing Record 33 of Set 3 | houma
# Processing Record 34 of Set 3 | georgiyevka
# Processing Record 35 of Set 3 | severo-kurilsk
# Processing Record 36 of Set 3 | verdun
# Processing Record 37 of Set 3 | vao
# Processing Record 38 of Set 3 | peterhead
# Processing Record 39 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 3 | bethel
# Processing Record 41 of Set 3 | codrington
# Processing Record 42 of Set 3 | ponta do sol
# Processing Record 43 of Set 3 | karasjok
# Processing Record 44 of Set 3 | adelaide
# Processing Record 45 of Set 3 | iqaluit
# Processing Record 46 of Set 3 | macaboboni
# City not found. Skipping...
# Processing Record 47 of Set 3 | saint-joseph
# Processing Record 48 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 3 | ouesso
# Processing Record 50 of Set 3 | bafoulabe
# Processing Record 1 of Set 4 | kristinehamn
# Processing Record 2 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 4 | rodrigues alves
# Processing Record 4 of Set 4 | nikolayevskaya
# Processing Record 5 of Set 4 | new norfolk
# Processing Record 6 of Set 4 | krasnoselkup
# Processing Record 7 of Set 4 | awjilah
# Processing Record 8 of Set 4 | yaqui
# Processing Record 9 of Set 4 | srednekolymsk
# Processing Record 10 of Set 4 | escarcega
# Processing Record 11 of Set 4 | cherskiy
# Processing Record 12 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 4 | avarua
# Processing Record 14 of Set 4 | tautira
# Processing Record 15 of Set 4 | sabang
# Processing Record 16 of Set 4 | deputatskiy
# Processing Record 17 of Set 4 | anloga
# Processing Record 18 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 19 of Set 4 | berlevag
# Processing Record 20 of Set 4 | palmer
# Processing Record 21 of Set 4 | coihaique
# Processing Record 22 of Set 4 | spokane
# Processing Record 23 of Set 4 | luganville
# Processing Record 24 of Set 4 | hasaki
# Processing Record 25 of Set 4 | kondinskoye
# Processing Record 26 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 4 | emba
# Processing Record 28 of Set 4 | luba
# Processing Record 29 of Set 4 | boralday
# Processing Record 30 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 4 | olenino
# Processing Record 32 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 33 of Set 4 | riyadh
# Processing Record 34 of Set 4 | tolaga bay
# Processing Record 35 of Set 4 | poronaysk
# Processing Record 36 of Set 4 | annaka
# Processing Record 37 of Set 4 | olafsvik
# Processing Record 38 of Set 4 | manaure
# Processing Record 39 of Set 4 | leningradskiy
# Processing Record 40 of Set 4 | tuktoyaktuk
# Processing Record 41 of Set 4 | honiara
# Processing Record 42 of Set 4 | maltahohe
# Processing Record 43 of Set 4 | pisco
# Processing Record 44 of Set 4 | nizwa
# Processing Record 45 of Set 4 | suntar
# Processing Record 46 of Set 4 | mehamn
# Processing Record 47 of Set 4 | saquena
# Processing Record 48 of Set 4 | kananga
# Processing Record 49 of Set 4 | hami
# Processing Record 50 of Set 4 | nyimba
# Processing Record 1 of Set 5 | popondetta
# Processing Record 2 of Set 5 | pombas
# Processing Record 3 of Set 5 | mao
# Processing Record 4 of Set 5 | fort nelson
# Processing Record 5 of Set 5 | ostrovnoy
# Processing Record 6 of Set 5 | nanortalik
# Processing Record 7 of Set 5 | arlit
# Processing Record 8 of Set 5 | bengkulu
# Processing Record 9 of Set 5 | pochutla
# Processing Record 10 of Set 5 | chuy
# Processing Record 11 of Set 5 | volterra
# Processing Record 12 of Set 5 | nsanje
# Processing Record 13 of Set 5 | narsaq
# Processing Record 14 of Set 5 | coquimbo
# Processing Record 15 of Set 5 | pousat
# City not found. Skipping...
# Processing Record 16 of Set 5 | messina
# Processing Record 17 of Set 5 | kismayo
# Processing Record 18 of Set 5 | lagoa
# Processing Record 19 of Set 5 | westlock
# Processing Record 20 of Set 5 | selma
# Processing Record 21 of Set 5 | talnakh
# Processing Record 22 of Set 5 | daru
# Processing Record 23 of Set 5 | preston
# Processing Record 24 of Set 5 | sept-iles
# Processing Record 25 of Set 5 | byron bay
# Processing Record 26 of Set 5 | tagab
# Processing Record 27 of Set 5 | bathsheba
# Processing Record 28 of Set 5 | carnarvon
# Processing Record 29 of Set 5 | beyneu
# Processing Record 30 of Set 5 | lixourion
# Processing Record 31 of Set 5 | yantai
# Processing Record 32 of Set 5 | kidal
# Processing Record 33 of Set 5 | inirida
# Processing Record 34 of Set 5 | mezen
# Processing Record 35 of Set 5 | odda
# Processing Record 36 of Set 5 | aykhal
# Processing Record 37 of Set 5 | baoning
# Processing Record 38 of Set 5 | nome
# Processing Record 39 of Set 5 | mackay
# Processing Record 40 of Set 5 | clyde river
# Processing Record 41 of Set 5 | rodos
# Processing Record 42 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 5 | ixtapa
# Processing Record 44 of Set 5 | upernavik
# Processing Record 45 of Set 5 | rio branco
# Processing Record 46 of Set 5 | kaitangata
# Processing Record 47 of Set 5 | tungor
# Processing Record 48 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 49 of Set 5 | marsabit
# Processing Record 50 of Set 5 | brownsville
# Processing Record 1 of Set 6 | santa rosa
# Processing Record 2 of Set 6 | baghmara
# Processing Record 3 of Set 6 | hofn
# Processing Record 4 of Set 6 | faanui
# Processing Record 5 of Set 6 | kota kinabalu
# Processing Record 6 of Set 6 | bunia
# Processing Record 7 of Set 6 | port elizabeth
# Processing Record 8 of Set 6 | alanya
# Processing Record 9 of Set 6 | mercedes
# Processing Record 10 of Set 6 | asau
# Processing Record 11 of Set 6 | hastings
# Processing Record 12 of Set 6 | arraial do cabo
# Processing Record 13 of Set 6 | dabou
# Processing Record 14 of Set 6 | vestmanna
# Processing Record 15 of Set 6 | brazzaville
# Processing Record 16 of Set 6 | walvis bay
# Processing Record 17 of Set 6 | batagay
# Processing Record 18 of Set 6 | seoul
# Processing Record 19 of Set 6 | vanavara
# Processing Record 20 of Set 6 | tiznit
# Processing Record 21 of Set 6 | marang
# Processing Record 22 of Set 6 | longyearbyen
# Processing Record 23 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 6 | barrow
# Processing Record 25 of Set 6 | katsuura
# Processing Record 26 of Set 6 | puerto escondido
# Processing Record 27 of Set 6 | port hardy
# Processing Record 28 of Set 6 | reserva
# Processing Record 29 of Set 6 | hamilton
# Processing Record 30 of Set 6 | jasdan
# Processing Record 31 of Set 6 | bozova
# Processing Record 32 of Set 6 | esperance
# Processing Record 33 of Set 6 | khartoum
# Processing Record 34 of Set 6 | aklavik
# Processing Record 35 of Set 6 | moree
# Processing Record 36 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 37 of Set 6 | zabol
# Processing Record 38 of Set 6 | nsoko
# Processing Record 39 of Set 6 | parfenyevo
# Processing Record 40 of Set 6 | coldwater
# Processing Record 41 of Set 6 | palana
# Processing Record 42 of Set 6 | wainwright
# Processing Record 43 of Set 6 | eureka
# Processing Record 44 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 6 | adrar
# Processing Record 46 of Set 6 | merke
# Processing Record 47 of Set 6 | litovko
# Processing Record 48 of Set 6 | teknaf
# Processing Record 49 of Set 6 | benguela
# Processing Record 50 of Set 6 | aksu
# Processing Record 1 of Set 7 | geraldton
# Processing Record 2 of Set 7 | iranshahr
# Processing Record 3 of Set 7 | bintulu
# Processing Record 4 of Set 7 | taft
# Processing Record 5 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 6 of Set 7 | karratha
# Processing Record 7 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 8 of Set 7 | lompoc
# Processing Record 9 of Set 7 | teneguiban
# City not found. Skipping...
# Processing Record 10 of Set 7 | perth
# Processing Record 11 of Set 7 | gulshat
# City not found. Skipping...
# Processing Record 12 of Set 7 | vila velha
# Processing Record 13 of Set 7 | myitkyina
# Processing Record 14 of Set 7 | balikpapan
# Processing Record 15 of Set 7 | nizhniy odes
# Processing Record 16 of Set 7 | vostok
# Processing Record 17 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 7 | cam ranh
# Processing Record 19 of Set 7 | bollnas
# Processing Record 20 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 7 | kericho
# Processing Record 22 of Set 7 | ballina
# Processing Record 23 of Set 7 | lorengau
# Processing Record 24 of Set 7 | mackenzie
# Processing Record 25 of Set 7 | pouebo
# Processing Record 26 of Set 7 | nakamura
# Processing Record 27 of Set 7 | safita
# Processing Record 28 of Set 7 | bandarbeyla
# Processing Record 29 of Set 7 | west bay
# Processing Record 30 of Set 7 | cidreira
# Processing Record 31 of Set 7 | pangody
# Processing Record 32 of Set 7 | atherton
# Processing Record 33 of Set 7 | cuamba
# Processing Record 34 of Set 7 | pearl
# Processing Record 35 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 36 of Set 7 | lakes entrance
# Processing Record 37 of Set 7 | omsukchan
# Processing Record 38 of Set 7 | nadym
# Processing Record 39 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 40 of Set 7 | dicabisagan
# Processing Record 41 of Set 7 | coos bay
# Processing Record 42 of Set 7 | port keats
# Processing Record 43 of Set 7 | mpanda
# Processing Record 44 of Set 7 | laguna
# Processing Record 45 of Set 7 | najran
# Processing Record 46 of Set 7 | camopi
# Processing Record 47 of Set 7 | madinat sittah uktubar
# Processing Record 48 of Set 7 | alofi
# Processing Record 49 of Set 7 | sakakah
# Processing Record 50 of Set 7 | korla
# Processing Record 1 of Set 8 | tarn taran
# Processing Record 2 of Set 8 | yar-sale
# Processing Record 3 of Set 8 | khawhai
# Processing Record 4 of Set 8 | carmen
# Processing Record 5 of Set 8 | mugur-aksy
# Processing Record 6 of Set 8 | mananara
# Processing Record 7 of Set 8 | cabra
# Processing Record 8 of Set 8 | zhigansk
# Processing Record 9 of Set 8 | angoram
# Processing Record 10 of Set 8 | bambous virieux
# Processing Record 11 of Set 8 | abnub
# Processing Record 12 of Set 8 | nikolskoye
# Processing Record 13 of Set 8 | gobabis
# Processing Record 14 of Set 8 | mitsamiouli
# Processing Record 15 of Set 8 | bodden town
# Processing Record 16 of Set 8 | fallon
# Processing Record 17 of Set 8 | naze
# Processing Record 18 of Set 8 | bonavista
# Processing Record 19 of Set 8 | meulaboh
# Processing Record 20 of Set 8 | yusva
# City not found. Skipping...
# Processing Record 21 of Set 8 | havre-saint-pierre
# Processing Record 22 of Set 8 | lhokseumawe
# Processing Record 23 of Set 8 | moquegua
# Processing Record 24 of Set 8 | mogadishu
# Processing Record 25 of Set 8 | tivaouane
# Processing Record 26 of Set 8 | yafran
# Processing Record 27 of Set 8 | gornja radgona
# Processing Record 28 of Set 8 | saint-augustin
# Processing Record 29 of Set 8 | tromso
# Processing Record 30 of Set 8 | lasa
# Processing Record 31 of Set 8 | nouadhibou
# Processing Record 32 of Set 8 | kenai
# Processing Record 33 of Set 8 | pilar
# Processing Record 34 of Set 8 | zhaoqing
# Processing Record 35 of Set 8 | constitucion
# Processing Record 36 of Set 8 | sohag
# Processing Record 37 of Set 8 | poum
# Processing Record 38 of Set 8 | yerbogachen
# Processing Record 39 of Set 8 | talavera de la reina
# Processing Record 40 of Set 8 | ossora
# Processing Record 41 of Set 8 | keti bandar
# Processing Record 42 of Set 8 | kainantu
# Processing Record 43 of Set 8 | izumo
# Processing Record 44 of Set 8 | norman wells
# Processing Record 45 of Set 8 | jatiroto
# Processing Record 46 of Set 8 | vikhorevka
# Processing Record 47 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 8 | kralendijk
# Processing Record 49 of Set 8 | yiyang
# Processing Record 50 of Set 8 | la libertad
# Processing Record 1 of Set 9 | loukhi
# Processing Record 2 of Set 9 | juneau
# Processing Record 3 of Set 9 | outjo
# Processing Record 4 of Set 9 | ati
# Processing Record 5 of Set 9 | kavieng
# Processing Record 6 of Set 9 | ulaangom
# Processing Record 7 of Set 9 | hirara
# Processing Record 8 of Set 9 | maceio
# Processing Record 9 of Set 9 | ahar
# Processing Record 10 of Set 9 | san cristobal
# Processing Record 11 of Set 9 | conde
# Processing Record 12 of Set 9 | cuenca
# Processing Record 13 of Set 9 | havelock
# Processing Record 14 of Set 9 | gubbi
# Processing Record 15 of Set 9 | bull savanna
# Processing Record 16 of Set 9 | vandavasi
# Processing Record 17 of Set 9 | chunhuhub
# Processing Record 18 of Set 9 | kerman
# Processing Record 19 of Set 9 | wonthaggi
# Processing Record 20 of Set 9 | hella
# Processing Record 21 of Set 9 | nakskov
# Processing Record 22 of Set 9 | birjand
# Processing Record 23 of Set 9 | bandundu
# Processing Record 24 of Set 9 | tual
# Processing Record 25 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 9 | gat
# Processing Record 27 of Set 9 | haines junction
# Processing Record 28 of Set 9 | jinchang
# Processing Record 29 of Set 9 | nova vicosa
# Processing Record 30 of Set 9 | nanning
# Processing Record 31 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 9 | paungde
# Processing Record 33 of Set 9 | vanimo
# Processing Record 34 of Set 9 | wangqing
# Processing Record 35 of Set 9 | port lincoln
# Processing Record 36 of Set 9 | raga
# Processing Record 37 of Set 9 | saldanha
# Processing Record 38 of Set 9 | sambava
# Processing Record 39 of Set 9 | mapiripan
# Processing Record 40 of Set 9 | millinocket
# Processing Record 41 of Set 9 | brokopondo
# Processing Record 42 of Set 9 | waitara
# Processing Record 43 of Set 9 | cabo san lucas
# Processing Record 44 of Set 9 | sorland
# Processing Record 45 of Set 9 | moose factory
# Processing Record 46 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 47 of Set 9 | tuatapere
# Processing Record 48 of Set 9 | harnai
# Processing Record 49 of Set 9 | tacuarembo
# Processing Record 50 of Set 9 | keflavik
# Processing Record 1 of Set 10 | saint-paul
# Processing Record 2 of Set 10 | port-cartier
# Processing Record 3 of Set 10 | acari
# Processing Record 4 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 5 of Set 10 | dunedin
# Processing Record 6 of Set 10 | muros
# Processing Record 7 of Set 10 | maniitsoq
# Processing Record 8 of Set 10 | mildura
# Processing Record 9 of Set 10 | methven
# Processing Record 10 of Set 10 | never
# Processing Record 11 of Set 10 | aleksandrovsk-sakhalinskiy
# Processing Record 12 of Set 10 | umm lajj
# Processing Record 13 of Set 10 | dombarovskiy
# Processing Record 14 of Set 10 | novyy urengoy
# Processing Record 15 of Set 10 | agadir
# Processing Record 16 of Set 10 | lufilufi
# Processing Record 17 of Set 10 | isla mujeres
# Processing Record 18 of Set 10 | mecca
# Processing Record 19 of Set 10 | perleberg
# Processing Record 20 of Set 10 | touros
# Processing Record 21 of Set 10 | marsa matruh
# Processing Record 22 of Set 10 | namuac
# Processing Record 23 of Set 10 | mayo
# Processing Record 24 of Set 10 | khandyga
# Processing Record 25 of Set 10 | broome
# Processing Record 26 of Set 10 | jos
# Processing Record 27 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 28 of Set 10 | sao felix do xingu
# Processing Record 29 of Set 10 | manavalakurichi
# Processing Record 30 of Set 10 | carlagan
# Processing Record 31 of Set 10 | huangmei
# Processing Record 32 of Set 10 | namwala
# Processing Record 33 of Set 10 | chaozhou
# Processing Record 34 of Set 10 | dalbandin
# Processing Record 35 of Set 10 | pascagoula
# Processing Record 36 of Set 10 | aswan
# Processing Record 37 of Set 10 | mmabatho
# Processing Record 38 of Set 10 | berdigestyakh
# Processing Record 39 of Set 10 | vallenar
# Processing Record 40 of Set 10 | lovozero
# Processing Record 41 of Set 10 | wladyslawowo
# Processing Record 42 of Set 10 | tongchuan
# Processing Record 43 of Set 10 | baran
# Processing Record 44 of Set 10 | komsomolskiy
# Processing Record 45 of Set 10 | avera
# Processing Record 46 of Set 10 | high rock
# Processing Record 47 of Set 10 | kulhudhuffushi
# Processing Record 48 of Set 10 | tiarei
# Processing Record 49 of Set 10 | olinda
# Processing Record 50 of Set 10 | vieira de leiria
# Processing Record 1 of Set 11 | ippy
# Processing Record 2 of Set 11 | kavaratti
# Processing Record 3 of Set 11 | makakilo city
# Processing Record 4 of Set 11 | mitchell
# Processing Record 5 of Set 11 | komatipoort
# Processing Record 6 of Set 11 | kindu
# Processing Record 7 of Set 11 | ladario
# Processing Record 8 of Set 11 | manono
# Processing Record 9 of Set 11 | sibolga
# Processing Record 10 of Set 11 | cockburn town
# Processing Record 11 of Set 11 | manacapuru
# Processing Record 12 of Set 11 | asyut
# Processing Record 13 of Set 11 | grand-santi
# Processing Record 14 of Set 11 | haimen
# Processing Record 15 of Set 11 | copiapo
# Processing Record 16 of Set 11 | half moon bay
# Processing Record 17 of Set 11 | jiuquan
# Processing Record 18 of Set 11 | kostomuksha
# Processing Record 19 of Set 11 | freeport
# Processing Record 20 of Set 11 | samfya
# Processing Record 21 of Set 11 | lubu
# Processing Record 22 of Set 11 | namatanai
# Processing Record 23 of Set 11 | synya
# Processing Record 24 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 25 of Set 11 | ducheng
# Processing Record 26 of Set 11 | biak
# Processing Record 27 of Set 11 | ciudad bolivar
# Processing Record 28 of Set 11 | annau
# Processing Record 29 of Set 11 | bilma
# Processing Record 30 of Set 11 | antofagasta
# Processing Record 31 of Set 11 | shache
# Processing Record 32 of Set 11 | nalut
# Processing Record 33 of Set 11 | great bend
# Processing Record 34 of Set 11 | malpe
# Processing Record 35 of Set 11 | sur
# Processing Record 36 of Set 11 | karatsu
# Processing Record 37 of Set 11 | huarmey
# Processing Record 38 of Set 11 | changchun
# Processing Record 39 of Set 11 | potosi
# Processing Record 40 of Set 11 | talcahuano
# Processing Record 41 of Set 11 | tilichiki
# Processing Record 42 of Set 11 | baruun-urt
# Processing Record 43 of Set 11 | manhattan
# Processing Record 44 of Set 11 | savonlinna
# Processing Record 45 of Set 11 | tura
# Processing Record 46 of Set 11 | nikki
# Processing Record 47 of Set 11 | savannah bight
# Processing Record 48 of Set 11 | katherine
# Processing Record 49 of Set 11 | show low
# Processing Record 50 of Set 11 | bosaso
# Processing Record 1 of Set 12 | lisakovsk
# Processing Record 2 of Set 12 | bilibino
# Processing Record 3 of Set 12 | wattegama
# Processing Record 4 of Set 12 | portland
# Processing Record 5 of Set 12 | shakawe
# Processing Record 6 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 7 of Set 12 | rawson
# Processing Record 8 of Set 12 | lazaro cardenas
# Processing Record 9 of Set 12 | zhengjiatun
# Processing Record 10 of Set 12 | bam
# Processing Record 11 of Set 12 | kashi
# Processing Record 12 of Set 12 | vanderhoof
# Processing Record 13 of Set 12 | souillac
# Processing Record 14 of Set 12 | la reforma
# Processing Record 15 of Set 12 | atbasar
# Processing Record 16 of Set 12 | hengshan
# Processing Record 17 of Set 12 | monrovia
# Processing Record 18 of Set 12 | conakry
# Processing Record 19 of Set 12 | kawalu
# Processing Record 20 of Set 12 | loandjili
# Processing Record 21 of Set 12 | pinheiral
# Processing Record 22 of Set 12 | salekhard
# Processing Record 23 of Set 12 | kibala
# Processing Record 24 of Set 12 | caravelas
# Processing Record 25 of Set 12 | acajutla
# Processing Record 26 of Set 12 | lavrentiya
# Processing Record 27 of Set 12 | uusikaupunki
# Processing Record 28 of Set 12 | tazovskiy
# Processing Record 29 of Set 12 | mabaruma
# Processing Record 30 of Set 12 | val-david
# Processing Record 31 of Set 12 | blonduos
# City not found. Skipping...
# Processing Record 32 of Set 12 | gunjur
# Processing Record 33 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 34 of Set 12 | neryungri
# Processing Record 35 of Set 12 | ruteng
# Processing Record 36 of Set 12 | nemuro
# Processing Record 37 of Set 12 | santa cruz
# Processing Record 38 of Set 12 | oktyabrskoye
# Processing Record 39 of Set 12 | kokopo
# Processing Record 40 of Set 12 | zyryanka
# Processing Record 41 of Set 12 | valparaiso
# Processing Record 42 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 43 of Set 12 | alto araguaia
# Processing Record 44 of Set 12 | homer
# Processing Record 45 of Set 12 | esna
# Processing Record 46 of Set 12 | hals
# Processing Record 47 of Set 12 | grande-riviere
# City not found. Skipping...
# Processing Record 48 of Set 12 | nelson bay
# Processing Record 49 of Set 12 | along
# Processing Record 50 of Set 12 | yatou
# Processing Record 1 of Set 13 | buraydah
# Processing Record 2 of Set 13 | omboue
# Processing Record 3 of Set 13 | marawi
# Processing Record 4 of Set 13 | chute-aux-outardes
# Processing Record 5 of Set 13 | dubti
# Processing Record 6 of Set 13 | tarakan
# Processing Record 7 of Set 13 | cotonou
# Processing Record 8 of Set 13 | llanes
# Processing Record 9 of Set 13 | sisimiut
# Processing Record 10 of Set 13 | maua
# Processing Record 11 of Set 13 | labuhan
# Processing Record 12 of Set 13 | kieta
# Processing Record 13 of Set 13 | beloha
# Processing Record 14 of Set 13 | banda aceh
# Processing Record 15 of Set 13 | sao fidelis
# Processing Record 16 of Set 13 | morrinhos
# Processing Record 17 of Set 13 | rupert
# Processing Record 18 of Set 13 | sehithwa
# Processing Record 19 of Set 13 | carballo
# Processing Record 20 of Set 13 | shediac
# Processing Record 21 of Set 13 | timbiqui
# Processing Record 22 of Set 13 | otradnoye
# Processing Record 23 of Set 13 | dudinka
# Processing Record 24 of Set 13 | halalo
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Nuevitas  21.5453  -77.2644     90.30        58           6
# 1            Kapaa  22.0752 -159.3190     78.78        83          89
# 2        Busselton -33.6500  115.3333     52.05        82          85
# 3  Novokizhinginsk  51.6115  109.5917     57.56        99         100
# 4      Bay Roberts  47.5999  -53.2648     59.02        95         100
# 5          Kahului  20.8947 -156.4700     74.97        89          97
# 6             Hilo  19.7297 -155.0900     80.28        94          90
# 7      Yellowknife  62.4560 -114.3525     68.29        77          75
# 8           Wajima  37.4000  136.9000     77.47        89           2
# 9           Camana -16.6228  -72.7111     66.25        69          16
#
#    Wind Speed Country                 Date
# 0       10.29      CU  2021-07-21 17:57:42
# 1        4.00      US  2021-07-21 17:57:43
# 2        7.65      AU  2021-07-21 17:57:43
# 3        2.73      RU  2021-07-21 17:57:43
# 4        8.01      CA  2021-07-21 17:56:44
# 5       11.34      US  2021-07-21 17:54:20
# 6        8.05      US  2021-07-21 17:57:44
# 7        3.00      CA  2021-07-21 17:57:44
# 8        6.64      JP  2021-07-21 17:57:45
# 9        6.58      PE  2021-07-21 17:57:45

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]
#new_column_order = ["City","Lat","Lng"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                 City Country                 Date      Lat       Lng  \
# 0           Nuevitas      CU  2021-07-21 17:57:42  21.5453  -77.2644
# 1              Kapaa      US  2021-07-21 17:57:43  22.0752 -159.3190
# 2          Busselton      AU  2021-07-21 17:57:43 -33.6500  115.3333
# 3    Novokizhinginsk      RU  2021-07-21 17:57:43  51.6115  109.5917
# 4        Bay Roberts      CA  2021-07-21 17:56:44  47.5999  -53.2648
# ..               ...     ...                  ...      ...       ...
# 571         Carballo      ES  2021-07-21 18:00:57  43.2130   -8.6910
# 572          Shediac      CA  2021-07-21 18:00:58  46.2198  -64.5411
# 573         Timbiqui      CO  2021-07-21 18:00:58   2.7717  -77.6654
# 574        Otradnoye      RU  2021-07-21 18:00:58  59.7775   30.8181
# 575          Dudinka      RU  2021-07-21 18:00:59  69.4058   86.1778
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0       90.30        58           6       10.29
# 1       78.78        83          89        4.00
# 2       52.05        82          85        7.65
# 3       57.56        99         100        2.73
# 4       59.02        95         100        8.01
# ..        ...       ...         ...         ...
# 571     77.58        91          65        5.26
# 572     71.10       100          90        6.91
# 573     84.36        74          69        8.21
# 574     65.17        52          58        7.45
# 575     55.40        59          63        9.08
#
# [576 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
